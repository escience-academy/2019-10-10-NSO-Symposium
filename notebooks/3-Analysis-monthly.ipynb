# %%
future = model.make_future_dataframe(periods=forecast_duration, freq='M')
forecast = model.predict(future)
fig = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)

# %%
fig=plt.figure(figsize=(16, 4), dpi= 80, facecolor='w', edgecolor='k')
# plt.plot(df['ds'], forecast['yhat'])
plt.plot(forecast['yhat'])
# plt.plot(forecast['yhat_lower'])
# plt.plot(forecast['yhat_upper'])
# plt.plot(forecast['yearly'])
# plt.plot(forecast['trend'])
# plt.label('Time')
plt.grid(False)

fig=plt.figure(figsize=(16, 4), dpi= 80, facecolor='w', edgecolor='k')
#plt.plot(df['ds'], df['y'])
plt.plot(df['y'])
plt.xlabel('Time')
plt.grid(False)
plt.show()
